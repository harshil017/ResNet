# %%
# Loading the dataset
from google.colab import drive
drive.mount('/content/drive')
train_dir = "drive/MyDrive/CatClassificationDataSet/train"
test_dir = "drive/MyDrive/CatClassificationDataSet/test/"
val_dir = "drive/MyDrive/CatClassificationDataSet/valid/"
# Out:
# Mounted at /content/drive

# %%
#Importing the necessary Libraries
import tensorflow as tf
# !pip install scikit-optimize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import layers, Model
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau, ModelCheckpoint
from skopt import gp_minimize
from skopt.space import Real
from keras.layers import Conv2D, Dense, BatchNormalization, Activation
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.0)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-23.5.9-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.22.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-23.5.9 scikit-optimize-0.9.0

# %%
#Preprocessing the Images 
tf.random.set_seed(42)
generator = ImageDataGenerator(rescale = 1./255.,
                              horizontal_flip=True,
                              vertical_flip=False,
                              zoom_range=0.05,
                              rotation_range=25)
train_data = generator.flow_from_directory(train_dir,
                                               batch_size=32, 
                                               target_size=(224, 224), 
                                               class_mode="categorical", 
                                               seed=42)

test_data = generator.flow_from_directory(test_dir,
                                               batch_size=32,
                                               target_size=(224, 224),
                                               class_mode="categorical",
                                               seed=42)

val_data = generator.flow_from_directory(val_dir,
                                               batch_size=32,
                                               target_size=(224, 224),
                                               class_mode="categorical",
                                               seed=42)
# Out:
# Found 2383 images belonging to 10 classes.
# Found 50 images belonging to 10 classes.
# Found 50 images belonging to 10 classes.

# %%
#Adding the Residual Block
def residual_block(x,filters,resnet_version,stride=1):
  shift = x
  #First Convolution Layer 
  conv = Conv2D(kernel_size=3,kernel_initializer='he_normal',kernel_regularizer=l2(0.001),padding='same',strides=stride,filters=3)
  #Second Convolution Layer
  conv2 =Conv2D(filters, kernel_size=3, strides=1, padding='same')
  
  if resnet_version == 2:  #Depending on the ResNet version it is convoluted first and then applying normalization and activation function or visa versa
    x =conv(x)
    x =conv2(x)
    x =BatchNormalization()(x)
    x =Activation('relu')(x)
  else:
    x =BatchNormalization()(x)
    x =Activation('relu')(x)
    x =conv(x)
    x =conv2(x)

  # Adjusting the shift for matching dimensions the residual network
  if stride != 1:
    shift = Conv2D(filters, kernel_size=1, strides=stride, padding='valid')(shift)
    shift = BatchNormalization()(shift)

  # Adding the shift i.e skip connection1
  x = layers.Add()([x, shift])
  x = layers.ReLU()(x)  

  return x

# %%
#Building the Resnet architecture that is based on the ResNet building resiudual block we defined above
def resnet_model(res_version,num_blocks,input_shape,num_classes):
  inputs = tf.keras.Input(shape=input_shape)
  x = Conv2D(64,kernel_size =3,strides = 1,padding='same')(inputs)
  x = BatchNormalization()(x)
  x = layers.ReLU()(x)
  strides = 2
  print("theno of blocks",num_blocks)
  for residual_block_1 in range(num_blocks):
    x = residual_block(x,64,res_version, stride= strides if residual_block_1 == 0 else 1)
  for residual_block_2 in range(num_blocks):
    x = residual_block(x,64,res_version, stride= strides if residual_block_2 == 0 else 1) 
  for residual_block_3 in range(num_blocks):
    x = residual_block(x,128,res_version, stride= strides if residual_block_3 == 0 else 1)
  for residual_block_4 in range(num_blocks):
    x = residual_block(x,256,res_version, stride= strides if residual_block_4 == 0 else 1) 
  x =  layers.AveragePooling2D(pool_size=8,padding='same')(x)
  x = layers.Flatten()(x)
  outputs = Dense(num_classes,activation='softmax')(x)
  model = Model(inputs=inputs,outputs=outputs)
  return model

# %%
import numpy as np
def model_call(resnetVersion,depth,input_shape,num_classes):
  print("here")
  if resnetVersion == 1:
    if (depth - 2)% 6 != 0:
      raise ValueError("Value of the depth should be of the form 6n+2")
    number_of_blocks = (depth - 2)/6
    number_of_blocks = int(number_of_blocks)
    final_model = resnet_model(resnetVersion,number_of_blocks,input_shape,num_classes)
  if resnetVersion == 2:
    if (depth - 2)% 9 != 0:
      raise ValueError("Value of the depth should be of the form 9n+2")
    number_of_blocks = (depth - 2)/9
    number_of_blocks = int(number_of_blocks) 
    final_model = resnet_model(resnetVersion,number_of_blocks,input_shape,num_classes)
  return final_model

# %%
resnetVersion = 1
if resnetVersion == 1:
  depth = 32
if resnetVersion == 2:
  depth = 29  
input_shape = (224, 224, 3)
num_classes = 10
batch_size = 32
epochs = 20
model = model_call(resnetVersion,depth,input_shape,num_classes)
print
model.compile(optimizer= Adam(learning_rate = 0.001),loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
print(model)
history = model.fit (train_data,batch_size=batch_size,epochs = epochs,shuffle=True, validation_data=(val_data))
scores = model.evaluate(test_data,verbose=1)
print("Test loss",scores[0])
print("Accuracy,",scores[1])
# Out:
# here
# theno of blocks 5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 224, 224, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 224, 64  256        ['re_lu[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 224, 224, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 3)  1731        ['activation[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 64  4160        ['re_lu[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 64  1792        ['conv2d_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 112, 112, 64  0           ['conv2d_2[0][0]',
#                                 )                                 'batch_normalization_2[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 112, 112, 64  0           ['add[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 64  256        ['re_lu_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 3)  1731        ['activation_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 64  1792        ['conv2d_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 112, 112, 64  0           ['conv2d_5[0][0]',
#                                 )                                 're_lu_1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 112, 112, 64  0           ['add_1[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 64  256        ['re_lu_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 112, 112, 3)  1731        ['activation_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 112, 112, 64  1792        ['conv2d_6[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 112, 112, 64  0           ['conv2d_7[0][0]',
#                                 )                                 're_lu_2[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 112, 112, 64  0           ['add_2[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 64  256        ['re_lu_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 112, 112, 3)  1731        ['activation_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 112, 112, 64  1792        ['conv2d_8[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 112, 112, 64  0           ['conv2d_9[0][0]',
#                                 )                                 're_lu_3[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 112, 112, 64  0           ['add_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 112, 112, 64  256        ['re_lu_4[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 112, 112, 3)  1731        ['activation_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 112, 112, 64  1792        ['conv2d_10[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 112, 112, 64  0           ['conv2d_11[0][0]',
#                                 )                                 're_lu_4[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 112, 112, 64  0           ['add_4[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 112, 112, 64  256        ['re_lu_5[0][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 3)    1731        ['activation_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 56, 56, 64)   4160        ['re_lu_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 64)   1792        ['conv2d_12[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_14[0][0]']
#  rmalization)
#
#  add_5 (Add)                    (None, 56, 56, 64)   0           ['conv2d_13[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 56, 56, 64)   0           ['add_5[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 64)  256         ['re_lu_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 56, 56, 3)    1731        ['activation_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 56, 56, 64)   1792        ['conv2d_15[0][0]']
#
#  add_6 (Add)                    (None, 56, 56, 64)   0           ['conv2d_16[0][0]',
#                                                                   're_lu_6[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 56, 56, 64)   0           ['add_6[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 64)  256         ['re_lu_7[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 56, 56, 3)    1731        ['activation_7[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 56, 56, 64)   1792        ['conv2d_17[0][0]']
#
#  add_7 (Add)                    (None, 56, 56, 64)   0           ['conv2d_18[0][0]',
#                                                                   're_lu_7[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 56, 56, 64)   0           ['add_7[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 56, 56, 64)  256         ['re_lu_8[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 56, 56, 3)    1731        ['activation_8[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 56, 56, 64)   1792        ['conv2d_19[0][0]']
#
#  add_8 (Add)                    (None, 56, 56, 64)   0           ['conv2d_20[0][0]',
#                                                                   're_lu_8[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 56, 56, 64)   0           ['add_8[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 64)  256         ['re_lu_9[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 56, 56, 3)    1731        ['activation_9[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 56, 56, 64)   1792        ['conv2d_21[0][0]']
#
#  add_9 (Add)                    (None, 56, 56, 64)   0           ['conv2d_22[0][0]',
#                                                                   're_lu_9[0][0]']
#
#  re_lu_10 (ReLU)                (None, 56, 56, 64)   0           ['add_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 56, 56, 64)  256         ['re_lu_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 3)    1731        ['activation_10[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 28, 28, 128)  8320        ['re_lu_10[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 128)  3584        ['conv2d_23[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 28, 28, 128)  0           ['conv2d_24[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  re_lu_11 (ReLU)                (None, 28, 28, 128)  0           ['add_10[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['re_lu_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 28, 28, 3)    3459        ['activation_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 28, 28, 128)  3584        ['conv2d_26[0][0]']
#
#  add_11 (Add)                   (None, 28, 28, 128)  0           ['conv2d_27[0][0]',
#                                                                   're_lu_11[0][0]']
#
#  re_lu_12 (ReLU)                (None, 28, 28, 128)  0           ['add_11[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 128)  512        ['re_lu_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 28, 28, 3)    3459        ['activation_12[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 28, 28, 128)  3584        ['conv2d_28[0][0]']
#
#  add_12 (Add)                   (None, 28, 28, 128)  0           ['conv2d_29[0][0]',
#                                                                   're_lu_12[0][0]']
#
#  re_lu_13 (ReLU)                (None, 28, 28, 128)  0           ['add_12[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 128)  512        ['re_lu_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 28, 28, 3)    3459        ['activation_13[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 28, 28, 128)  3584        ['conv2d_30[0][0]']
#
#  add_13 (Add)                   (None, 28, 28, 128)  0           ['conv2d_31[0][0]',
#                                                                   're_lu_13[0][0]']
#
#  re_lu_14 (ReLU)                (None, 28, 28, 128)  0           ['add_13[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 128)  512        ['re_lu_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 28, 28, 3)    3459        ['activation_14[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 28, 28, 128)  3584        ['conv2d_32[0][0]']
#
#  add_14 (Add)                   (None, 28, 28, 128)  0           ['conv2d_33[0][0]',
#                                                                   're_lu_14[0][0]']
#
#  re_lu_15 (ReLU)                (None, 28, 28, 128)  0           ['add_14[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 128)  512        ['re_lu_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 3)    3459        ['activation_15[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 256)  33024       ['re_lu_15[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 256)  7168        ['conv2d_34[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 14, 14, 256)  0           ['conv2d_35[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  re_lu_16 (ReLU)                (None, 14, 14, 256)  0           ['add_15[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 256)  1024       ['re_lu_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 3)    6915        ['activation_16[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 256)  7168        ['conv2d_37[0][0]']
#
#  add_16 (Add)                   (None, 14, 14, 256)  0           ['conv2d_38[0][0]',
#                                                                   're_lu_16[0][0]']
#
#  re_lu_17 (ReLU)                (None, 14, 14, 256)  0           ['add_16[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 256)  1024       ['re_lu_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 3)    6915        ['activation_17[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 256)  7168        ['conv2d_39[0][0]']
#
#  add_17 (Add)                   (None, 14, 14, 256)  0           ['conv2d_40[0][0]',
#                                                                   're_lu_17[0][0]']
#
#  re_lu_18 (ReLU)                (None, 14, 14, 256)  0           ['add_17[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 256)  1024       ['re_lu_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 3)    6915        ['activation_18[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 256)  7168        ['conv2d_41[0][0]']
#
#  add_18 (Add)                   (None, 14, 14, 256)  0           ['conv2d_42[0][0]',
#                                                                   're_lu_18[0][0]']
#
#  re_lu_19 (ReLU)                (None, 14, 14, 256)  0           ['add_18[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 256)  1024       ['re_lu_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 3)    6915        ['activation_19[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 256)  7168        ['conv2d_43[0][0]']
#
#  add_19 (Add)                   (None, 14, 14, 256)  0           ['conv2d_44[0][0]',
#                                                                   're_lu_19[0][0]']
#
#  re_lu_20 (ReLU)                (None, 14, 14, 256)  0           ['add_19[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 256)  1024       ['re_lu_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 3)      6915        ['activation_20[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 512)    131584      ['re_lu_20[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 512)    14336       ['conv2d_45[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_47[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 7, 7, 512)    0           ['conv2d_46[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  re_lu_21 (ReLU)                (None, 7, 7, 512)    0           ['add_20[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 7, 7, 512)   2048        ['re_lu_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 3)      13827       ['activation_21[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 512)    14336       ['conv2d_48[0][0]']
#
#  add_21 (Add)                   (None, 7, 7, 512)    0           ['conv2d_49[0][0]',
#                                                                   're_lu_21[0][0]']
#
#  re_lu_22 (ReLU)                (None, 7, 7, 512)    0           ['add_21[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 7, 7, 512)   2048        ['re_lu_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_28[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 3)      13827       ['activation_22[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 512)    14336       ['conv2d_50[0][0]']
#
#  add_22 (Add)                   (None, 7, 7, 512)    0           ['conv2d_51[0][0]',
#                                                                   're_lu_22[0][0]']
#
#  re_lu_23 (ReLU)                (None, 7, 7, 512)    0           ['add_22[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 512)   2048        ['re_lu_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 3)      13827       ['activation_23[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 512)    14336       ['conv2d_52[0][0]']
#
#  add_23 (Add)                   (None, 7, 7, 512)    0           ['conv2d_53[0][0]',
#                                                                   're_lu_23[0][0]']
#
#  re_lu_24 (ReLU)                (None, 7, 7, 512)    0           ['add_23[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 7, 7, 512)   2048        ['re_lu_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_30[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 3)      13827       ['activation_24[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 512)    14336       ['conv2d_54[0][0]']
#
#  add_24 (Add)                   (None, 7, 7, 512)    0           ['conv2d_55[0][0]',
#                                                                   're_lu_24[0][0]']
#
#  re_lu_25 (ReLU)                (None, 7, 7, 512)    0           ['add_24[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 512)   0           ['re_lu_25[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 512)          0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 10)           5130        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 480,789
# Trainable params: 469,269
# Non-trainable params: 11,520
# __________________________________________________________________________________________________
# <keras.engine.functional.Functional object at 0x7f8eb54fb460>
# Epoch 1/20
# 75/75 [==============================] - 1586s 21s/step - loss: 2.0518 - accuracy: 0.2803 - val_loss: 4.4436 - val_accuracy: 0.1000
# Epoch 2/20
# 75/75 [==============================] - 1553s 21s/step - loss: 1.7373 - accuracy: 0.3915 - val_loss: 8.8622 - val_accuracy: 0.1000
# Epoch 3/20
# 21/75 [=======>......................] - ETA: 18:21 - loss: 1.5733 - accuracy: 0.4375
